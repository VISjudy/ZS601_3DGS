# %% [markdown]
# # 3DGS 标准实验模板
# 按环境→数据→测试→冒烟→正式训练→验收→Drive 回读顺序显式执行。

# %% [markdown]
# ## 1. Python、CUDA 与 GPU 检查

# %%
import subprocess,sys
print(sys.version)
print(subprocess.check_output(['nvidia-smi'],text=True))

# %% [markdown]
# ## 2. 挂载 Drive 与新 RUN_ID

# %%
from google.colab import drive
drive.mount('/content/drive')
PROJECT='replace_me'
RUN_ID='replace_with_unique_id'
EXPERIMENT_GROUP='custom'

# %% [markdown]
# ## 3. 克隆固定提交

# %%
REPO_URL='https://github.com/OWNER/REPO.git'
GIT_COMMIT='replace_with_commit'
# 使用 subprocess.run 克隆并 checkout 固定提交；正式实验不使用浮动分支。

# %% [markdown]
# ## 4. 安装依赖、编译 CUDA 扩展、运行测试

# %%
# 在这里填写项目真实安装和测试命令，并保留完整输出。

# %% [markdown]
# ## 5. Drive 数据复制到 /content 本地

# %%
# 原始 Drive 数据只读；复制到 /content/datasets/<scene>。

# %% [markdown]
# ## 6. 数据预处理和独立验证

# %%
# 依次运行相机/SfM、点云、监督图和 validate 阶段。

# %% [markdown]
# ## 7. 200 步冒烟（保持正式学习率 horizon）

# %%
# 输出 iteration 0 和 200 诊断、checkpoint、verification.json。

# %% [markdown]
# ## 8. 正式训练

# %%
# 冒烟通过后使用新的输出目录启动正式训练。

# %% [markdown]
# ## 9. 完整 test、最终点云几何评估、结果表和验收
# 先对全部 test 相机计算 PSNR/SSIM/MAE 并保存最差 10 相机诊断，再尝试最终几何评估。项目格式不同先通过 adapter 转成 PLY/NPY/NPZ。无法可靠计算的指标写入 evaluation_status.json，汇总中保留 null 和原因。

# %%
# 1) 运行项目自己的完整 test 与最差10诊断。
# 2) 尝试几何评估：
# !python scripts/evaluate_geometry.py --prediction "$RUN_DIR/point_cloud/iteration_150000/point_cloud.ply" --reference "$REFERENCE_CLOUD" --reference-role initialization_lidar --unit meters --output "$RUN_DIR/geometry_test"
# 3) 写 evaluation_status.json，completed 或 skipped 均需带明确状态，skipped 必须有原因。
# 4) 汇总和验收：
# !python scripts/summarize_experiment.py "$RUN_DIR" --iterations 150000
# !python scripts/verify_run_outputs.py "$RUN_DIR" --profile formal --iterations 150000 --output verification.json

# %% [markdown]
# ## 10. 复制回 Drive、回读并释放 GPU

# %%
# 回读 verification/completed/checkpoints/test 后才释放 GPU。
